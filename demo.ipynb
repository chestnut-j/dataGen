# %%
# origin = [{
#   "(( $Length(10) $Opt $Length(20) $Opt $Length(50) ) $And ( $StableDistribution(Data) $Opt $BlowUpDistribution(Data) ))": {
#       "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
#       "Data": "$Int $And $Range(0,500)"
#   }
# }]
origin = [{
  "( ($Length(10) $Opt $Length(20)) $And $BlowUpDistribution(index) $And ($ColNum(6) $Opt $ColNum(10)) )": {
      "index": "$Int $And ( $Range(0,20) $Opt $Range(10,50))",
      "col1": "$Int $And ($Repeat(5,5) $Opt $Repeat(2,2)) $And $Empty(1)",
      "col2": "$String $And ($Empty(5) $Or $Repeat('a',2))",
      "col3": "$Int $And $Frequency(6, 0.4, 5, 0.3) $And $Empty(2)",
      "col4": "$Real $And $FreqIf(>6, 0.4)",
      "col5": "$Real $And $Range(0, 400)",
      "col5": "$Faker(name) $And $Empty(1) $And $Repeat(3)",
      "col6": "$Faker(phone_number)",
  }
}]

# %%
# 解析器函数定义
from itertools import product
import numpy as np

def findPosi(allStr, findStr):
    #用于存储findStr标识符的出现
    posiList = []
    #是否有findStr的标识符
    findPosi = False
    findOption = False
    #先确定是否存在findStr标识符并获取其位置
    if allStr.find(findStr) != -1:
        posiList.append(allStr.find(findStr))
        #已找到当前的posiStr位置，可以继续寻找下一个
        findOption = True
        #下一个标识符开始寻找的位置
        findPosi = allStr.find(findStr) + 1
    #寻找约束中剩余的findStr标识符
    while(findOption):
        if allStr.find(findStr, findPosi) != -1:
            posiList.append(allStr.find(findStr, findPosi))
            findPosi = allStr.find(findStr, findPosi) + 1
        else:
            findOption = False
            
    return posiList

def optionSoluntion(optionList):
    optionResult = []
    for option in product(*optionList):
        tempList = []
        for i in option:
            tempList.append(i)
        optionResult.append(tempList)
    return optionResult

def orSoluntion(optionList):
    optionResult = []
    for option in optionList:
        optionResult.append(option[np.random.randint(0,len(option))])
    return optionResult


def removeOrOp(constraint):
    optionPosiList = findPosi(constraint, "$Or")
     # 根据option标识符的位置把constraint分割为多个部分
    constraintList = []
    for i in range(0, len(optionPosiList)):
        if i == 0 and len(optionPosiList) == 1:
            constraintList.append(constraint[0:optionPosiList[i]])
            constraintList.append(constraint[optionPosiList[i] + 3:])
        elif i == 0 and len(optionPosiList) != 1:
            constraintList.append(constraint[0:optionPosiList[i]])
        elif i == len(optionPosiList) - 1:
            constraintList.append(constraint[optionPosiList[i-1] + 3: optionPosiList[i]])
            constraintList.append(constraint[optionPosiList[i] + 3:])
        else:
            constraintList.append(constraint[optionPosiList[i-1] + 3: optionPosiList[i]])
     # 根据括号寻找slot的位置
    count = 0
    slotContentList = []
    tempSlotContent = []
    slotJson = ""
    isOnlyOption = True

    for constraintStr in constraintList:
        #用于存储前括号的位置信息
        frontParenthesisList = findPosi(constraintStr, '(')
        #用于存储后括号的位置信息
        backParenthesisList = findPosi(constraintStr, ')')
        if count == 0:
            slotParenthesis = len(backParenthesisList) + 1
            slotStart = frontParenthesisList[slotParenthesis - 1]
            tempSlotContent.append(constraintStr[slotStart + 1:])
            slotJson += constraintStr[:slotStart]
            slotJson += "{"
        # 处理字符串中只有条件的情况
        elif len(frontParenthesisList) == len(backParenthesisList):
            isOnlyOption = True
            for position in range(0, len(frontParenthesisList)):
                if frontParenthesisList[position] > backParenthesisList[position]:
                    isOnlyOption = False
                    break
            if isOnlyOption:
                tempSlotContent.append(constraintStr)
            else:
                slotEnd = backParenthesisList[slotParenthesis - 1]
                tempSlotContent.append(constraintStr[:slotEnd])
                slotContentList.append(tempSlotContent)
                slotJson += "}"
                tempSlotContent = []
                if len(frontParenthesisList) - len(backParenthesisList) + slotParenthesis > 0:
                    nextSlotParenthesis = len(frontParenthesisList) + slotParenthesis - len(backParenthesisList)
                    slotParenthesis = nextSlotParenthesis
                    slotStart = frontParenthesisList[-slotParenthesis]
                    slotJson += constraintStr[slotEnd + 1:slotStart]
                    tempSlotContent.append(constraintStr[slotStart + 1:])
                    slotJson += "{"
                else:
                    slotJson += constraintStr[slotEnd + 1:]
        else:
            slotEnd = backParenthesisList[slotParenthesis - 1]
            tempSlotContent.append(constraintStr[:slotEnd])
            slotContentList.append(tempSlotContent)
            slotJson += "}"
            tempSlotContent = []
            if len(frontParenthesisList) - len(backParenthesisList) + slotParenthesis > 0:
                nextSlotParenthesis = len(frontParenthesisList) + slotParenthesis - len(backParenthesisList)
                slotParenthesis = nextSlotParenthesis
                slotStart = frontParenthesisList[slotParenthesis - 1]
                slotJson += constraintStr[slotEnd + 1:slotStart]
                tempSlotContent.append(constraintStr[slotStart + 1:])
                slotJson += "{"
            else:
                slotJson += constraintStr[slotEnd + 1:]
        count += 1
    
    optionResult = orSoluntion(slotContentList)
    
    finalJson = ''
    finalJson = slotJson.format(*optionResult)[1:-1]
    
    return finalJson


def parseConstraint(rawConstraint):
    
    
    constraint = rawConstraint.replace(" ","")

    if constraint.find('$Opt') == -1:
        return [constraint[1:-1]]
    
    optionPosiList = findPosi(constraint, "$Opt")
    print(optionPosiList)
    
    isOnlyOption = False
            
    # 根据option标识符的位置把constraint分割为多个部分
    constraintList = []
    for i in range(0, len(optionPosiList)):
        if i == 0 and len(optionPosiList) == 1:
            constraintList.append(constraint[0:optionPosiList[i]])
            constraintList.append(constraint[optionPosiList[i] + 4:])
        elif i == 0 and len(optionPosiList) != 1:
            constraintList.append(constraint[0:optionPosiList[i]])
        elif i == len(optionPosiList) - 1:
            constraintList.append(constraint[optionPosiList[i-1] + 4: optionPosiList[i]])
            constraintList.append(constraint[optionPosiList[i] + 4:])
        else:
            constraintList.append(constraint[optionPosiList[i-1] + 4: optionPosiList[i]])
    # 根据括号寻找slot的位置
    print(constraintList)
    count = 0
    slotContentList = []
    tempSlotContent = []
    slotJson = ""

    for constraintStr in constraintList:
        #用于存储前括号的位置信息
        frontParenthesisList = findPosi(constraintStr, '(')
        #用于存储后括号的位置信息
        backParenthesisList = findPosi(constraintStr, ')')
        if count == 0:
            slotParenthesis = len(backParenthesisList) + 1
            slotStart = frontParenthesisList[slotParenthesis - 1]
            tempSlotContent.append(constraintStr[slotStart + 1:])
            slotJson += constraintStr[:slotStart]
            slotJson += "{"
        # 处理字符串中只有条件的情况
        elif len(frontParenthesisList) == len(backParenthesisList):
            isOnlyOption = True
            for position in range(0, len(frontParenthesisList)):
                if frontParenthesisList[position] > backParenthesisList[position]:
                    isOnlyOption = False
                    break
            if isOnlyOption:
                tempSlotContent.append(constraintStr)
            else:
                slotEnd = backParenthesisList[slotParenthesis - 1]
                tempSlotContent.append(constraintStr[:slotEnd])
                slotContentList.append(tempSlotContent)
                slotJson += "}"
                tempSlotContent = []
                if len(frontParenthesisList) - len(backParenthesisList) + slotParenthesis > 0:
                    nextSlotParenthesis = len(frontParenthesisList) + slotParenthesis - len(backParenthesisList)
                    slotParenthesis = nextSlotParenthesis
                    slotStart = frontParenthesisList[-(slotParenthesis)]
                    slotJson += constraintStr[slotEnd + 1:slotStart]
                    tempSlotContent.append(constraintStr[slotStart + 1:])
                    slotJson += "{"
                else:
                    slotJson += constraintStr[slotEnd + 1:]
        else:
            slotEnd = backParenthesisList[slotParenthesis - 1]
            tempSlotContent.append(constraintStr[:slotEnd])
            slotContentList.append(tempSlotContent)
            slotJson += "}"
            tempSlotContent = []
            if len(frontParenthesisList) - len(backParenthesisList) + slotParenthesis > 0:
                nextSlotParenthesis = len(frontParenthesisList) + slotParenthesis - len(backParenthesisList)
                slotParenthesis = nextSlotParenthesis
                slotStart = frontParenthesisList[slotParenthesis - 1]
                slotJson += constraintStr[slotEnd + 1:slotStart]
                tempSlotContent.append(constraintStr[slotStart + 1:])
                slotJson += "{"
            else:
                slotJson += constraintStr[slotEnd + 1:]
        count += 1
    
    optionResult = optionSoluntion(slotContentList)
    
    finalJsonList = []
    for ri in optionResult:
        finalJsonList.append(slotJson.format(*ri)[1:-1])
    
    return finalJsonList

# %%
from itertools import product
allTables = []
for format in origin:
  
  test = []
  remainValue = {}
  value_test = []
  key_test = []
  for key, value in format.items():
    test = parseConstraint(key)
    remainValue = value
    # print(value.items())
    for col_key, col_value in value.items():
      value_test.append(parseConstraint('( '+col_value+' )'))
      key_test.append(col_key)
  valueList = []
  valueList = product(*value_test)
  for value_op in valueList:
    for op in test:
      parseFormat = []
      item = {}
      valueFormat = {}
      for i in range(len(key_test)):
        if value_op[i].find('$Or') != -1:
          valueFormat[key_test[i]] = removeOrOp('('+value_op[i]+')')
        else:
          valueFormat[key_test[i]] = value_op[i] 
      item[op] = valueFormat
      parseFormat.append(item)
      allTables.append(parseFormat)
      
      
  # for op in test:
  #     parseFormat = []
  #     item = {}
  #     item[op] = remainValue
  #     parseFormat.append(item)
  #     allTables.append(parseFormat)
allTables
# Out:
# [13, 74]
# ['(($Length(10)', '$Length(20))$And$BlowUpDistribution(index)$And($ColNum(6)', '$ColNum(10)))']
# [22]
# ['($Int$And($Range(0,20)', '$Range(10,50)))']
# [22]
# ['($Int$And($Repeat(5,5)', '$Repeat(2,2))$And$Empty(1))']
# [[{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': "$String$And$Repeat('a',2)",
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': "$String$And$Repeat('a',2)",
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(0,20)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': "$String$And$Repeat('a',2)",
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': "$String$And$Repeat('a',2)",
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(5,5)$And$Empty(1)',
#     'col2': "$String$And$Repeat('a',2)",
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(10)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(6)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}],
#  [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(10,50)',
#     'col1': '$Int$And$Repeat(2,2)$And$Empty(1)',
#     'col2': '$String$And$Empty(5)',
#     'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)',
#     'col4': '$Real$And$FreqIf(>6,0.4)',
#     'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)',
#     'col6': '$Faker(phone_number)'}}]]

# %%
# 解析
target = [
  [{
    "( $Length(10)  $And  $StableDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
  [{
    "( $Length(10)  $And  $BlowUpDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
  [{
    "( $Length(20)  $And  $StableDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
  [{
    "( $Length(20)  $And  $BlowUpDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
  [{
    "( $Length(50)  $And  $StableDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
  [{
    "( $Length(50)  $And  $BlowUpDistribution(Data) )": {
        "month": "$Date $And $DateData('2018-01', '2022-12', 'YYYY-MM', successive = True)",
        "Data": "$Int $And $Range(0,500)"
    }
  }],
]

# %%
# 单表映射函数定义
def findPosition(allStr, findStr):
    #用于存储findStr标识符的出现
    posiList = []
    #是否有findStr的标识符
    findPosi = False
    findOption = False
    #先确定是否存在findStr标识符并获取其位置
    if allStr.find(findStr) != -1:
        posiList.append(allStr.find(findStr))
        #已找到当前的posiStr位置，可以继续寻找下一个
        findOption = True
        #下一个标识符开始寻找的位置
        findPosi = allStr.find(findStr) + 1
    #寻找约束中剩余的findStr标识符
    while(findOption):
        if allStr.find(findStr, findPosi) != -1:
            posiList.append(allStr.find(findStr, findPosi))
            findPosi = allStr.find(findStr, findPosi) + 1
        else:
            findOption = False
            
    return posiList
  
def findConstrain(allStr, operation):
    constraint = allStr.replace(" ","")
    if constraint[0] == '(' and constraint[len(constraint)-1] == ')':
        constraint = constraint[1:len(constraint)-1]
    opList = findPosition(constraint, operation)
    opLen = len(operation)
    constraintList = []
    for i in range(0, len(opList)):
        if i == 0 and len(opList) == 1:
            constraintList.append(constraint[0:opList[i]])
            constraintList.append(constraint[opList[i] + opLen:])
        elif i == 0 and len(opList) != 1:
            constraintList.append(constraint[0:opList[i]])
        elif i == len(opList) - 1:
            constraintList.append(constraint[opList[i-1] + opLen: opList[i]])
            constraintList.append(constraint[opList[i] + opLen:])
        else:
            constraintList.append(constraint[opList[i-1] + opLen: opList[i]])
    return constraintList


def parseCons(cons, col):
  # parse type
  if cons == '$Int':
    col['type'] = 'Int'
  if cons == '$Real':
    col['type'] = 'Real'
  if cons == '$String':
    col['type'] = 'String'
  if cons == '$Date':
    col['type'] = 'Date'
  
  if cons.find('DateData')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    col['range'] = [eval(args[0]),eval(args[1])]
    col['format'] = eval(args[2])
    if eval(args[2]) == 'YYYY-MM-DD':
      col['freq'] = 'D'
    if eval(args[2]) == 'YYYY-MM':
      col['freq'] = 'M'
    if eval(args[2]) == 'YYYY':
      col['freq'] = 'Y'
  
  if cons.find('Faker')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    col['type'] = 'Faker'
    col['content'] = args[0]
    if len(args)==2:
      col['locale'] = args[1]

  if cons.find('Range')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    col['range'] = [eval(args[0]),eval(args[1])]

  if cons.find('Repeat')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    if 'repeat' in col:
      col['repeat'] = col['repeat'] + [eval(x) for x in args]
    else:
      col['repeat'] = [eval(x) for x in args]
  
  if cons.find('Frequency')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    if 'frequency' in col:
      col['frequency'] = col['frequency'] + [eval(x) for x in args]
    else:
      col['frequency'] = [eval(x) for x in args]

  if cons.find('Empty')!= -1:
    args = cons[cons.find('(')+1:cons.find(')')].split(',')
    col['empty'] = eval(args[0])

# %%
# 单表映射
tables = []
for table in allTables:
  tableParse = []
  for element in table:
    for key,value in element.items():
      format = {
        'children': []
      }
      # parse children
      for col_key, col_value in value.items():
        col = {}
        col['name'] = col_key
        consList = findConstrain(col_value, '$And')
        if len(consList) == 0:
          consList.append(col_value)
        for cons in consList:
          parseCons(cons, col)
        format['children'].append(col)
      # parse key
      constrainList = findConstrain(key, '$And')
      for cons in constrainList:
        if cons.find('Length') != -1:
          arg = cons[cons.find('(')+1:cons.find(')')]
          format['length'] = int(arg)
        if cons.find('ColNum') != -1:
          arg = cons[cons.find('(')+1:cons.find(')')]
          format['colNum'] = int(arg)
        if cons.find('Distribution'):
          arg = cons[cons.find('(')+1:cons.find(')')]
          dis_type = cons[cons.find('$')+1:cons.find('Distribution')]
          for child in format['children']:
            if child['name'] == arg:
              child['distribution'] = dis_type
      # 补充其余列
      if(len(value.items())<format['colNum']):
        for i in range(format['colNum']-len(value.items())):
          col = {}
          col['name'] = 'col'+str(len(value.items())+i+1)
          format['children'].append(col)
      tableParse.append(format)
  tables.append(tableParse)

tables
# Out:
# [[{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 10,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 10,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 20,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 20,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 10,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 10,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 20,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [0, 20],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 20,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 10,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 10,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 20,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 20,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 10,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 10,
#    'colNum': 10}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}],
#    'length': 20,
#    'colNum': 6}],
#  [{'children': [{'name': 'index',
#      'type': 'Int',
#      'range': [10, 50],
#      'distribution': 'BlowUp'},
#     {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1},
#     {'name': 'col2', 'type': 'String', 'empty': 5},
#     {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2},
#     {'name': 'col4', 'type': 'Real'},
#     {'name': 'col5',
#      'type': 'Faker',
#      'content': 'name',
#      'empty': 1,
#      'repeat': [3]},
#     {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'},
#     {'name': 'col8'},
#     {'name': 'col9'},
#     {'name': 'col10'}],
#    'length': 20,
#    'colNum': 10}]]

# %%
# 求解
import z3
import pandas as pd
import csv
import numpy as np
from faker import Faker

def date_format_match(format):
  if format == 'YYYY-MM-DD':
    return '%Y-%m-%d'
  if format == 'YYYY-MM':
    return '%Y-%m'
  if format == 'YYYY':
    return '%Y'

def solveDate(config):
  data = pd.date_range(config['range'][0], config['range'][1], freq=config['freq']).strftime(date_format_match(config['format']))
  return data

def solveFaker(config, len):
  if 'locale' in config:
    fk = Faker(locale=config['locale'])
  else:
    fk = Faker(locale='zh-CN')
  data = [eval('faker.'+config['content']+'()',{'faker': fk}) for i in range(len)]

  unselected_index = np.arange(num_len)
  if 'repeat' in config and not 'distribution' in config:
    times = col['repeat']
    repeat_index = np.random.choice(unselected_index, times, replace=False)
    for index in repeat_index:
      data[index] = data[repeat_index[0]]
    unselected_index = [elem for elem in unselected_index if elem not in repeat_index]
    
  if 'empty' in config and not 'distribution' in config:
    times = col['empty']
    empty_index = np.random.choice(unselected_index, times, replace=False)
    print(empty_index)
    for index in empty_index:
      data[index] = None
  
  

  return data

def parse2csv(data_list,name):
  csv_fp = open('./data/'+name+'test_csv.csv','w',encoding='utf-8',newline='')
  print(data_list)
  sheet_title = data_list[0].keys()
  sheet_data = []
  for data in data_list:
    sheet_data.append(data.values())
  writer = csv.writer(csv_fp)
  writer.writerow(sheet_title)
  writer.writerows(sheet_data)
  csv_fp.close()

AllRes = []
for index in range(len(tables)):
  print('soving table……')
  print(table)
  table = tables[index]
  res = []
  for format in table:
    num_len = format['length']
    columns = format['children']
    col_size = format['colNum']
    
    d = {}
    others = {}

    solver = z3.Solver()

    for col in columns:
      special_value = 0
      special_index = []
      random_list = []
      #define type
      if 'type' in col:
        col_type = col['type'] 
        if col_type == 'Int':
          d[col['name']] = [z3.Int(f"{col['name']}_{i}") for i in range(num_len)]
        if col_type == 'Real':
          d[col['name']] = [z3.Real(f"{col['name']}_{i}") for i in range(num_len)]
        if col_type == 'String':
          d[col['name']] = [z3.String(f"{col['name']}_{i}") for i in range(num_len)]
        if col_type == 'Date':
          others[col['name']] = solveDate(col)
          continue
        if col_type == 'Faker':
          # random_list = solveFaker(col,num_len)
          others[col['name']] = solveFaker(col,num_len)
          continue
      else:
        d[col['name']] = [z3.Int(f"{col['name']}_{i}") for i in range(num_len)]
      #define range
      if 'range' in col:
        col_range = col['range']
        if col_type == 'Int' or col_type == 'Real':
          range_c = [z3.And(d[col['name']][i]>=col_range[0], d[col['name']][i]<=col_range[1]) for i in range(num_len)]
          solver.add(range_c)
          # seed = round(np.random.uniform(col_range[0],col_range[1]),1)
          # print(seed)
          # avg_c = z3.Sum([d[col['name']][i]for i in range(num_len)]) == num_len * seed
          # if not('distribution' in col):
          #   solver.add(avg_c)
        if col_type == 'Int':
          random_list = [round(np.random.uniform(col_range[0],col_range[1]),0) for i in range(num_len)]
        elif col_type == 'Real':
          random_list = [round(np.random.uniform(col_range[0],col_range[1]),2) for i in range(num_len)]
      else:
        # if col_type == 'Int' or col_type == 'Real':
        #   # range_c = [d[col['name']][i]>=0 for i in range(num_len)]          
        #   # solver.add(range_c)
        #   seed = round(np.random.uniform(0,100),1)
        #   avg_c = z3.Sum([d[col['name']][i]for i in range(num_len)]) == num_len * seed
        #   solver.add(avg_c)
        if col_type == 'Int':
          random_list = [round(np.random.uniform(0,100),0) for i in range(num_len)]
        elif col_type == 'Real':
          random_list = [round(np.random.uniform(0,100),2) for i in range(num_len)]
          
      #define repeat
      if 'repeat' in col:
        for i in range(int(len(col['repeat'])/2)):
          content = col['repeat'][2*i]
          times = col['repeat'][2*i+1]
          special_value += times
          
          repeat_c = z3.Sum([d[col['name']][i]==content for i in range(num_len)]) == times
          solver.add(repeat_c)

      #define frequency
      if 'frequency' in col:
        for i in range(int(len(col['frequency'])/2)):
          content = col['frequency'][2*i]
          times = col['frequency'][2*i+1]
          special_value += num_len * times
          frequency_c = z3.Sum([d[col['name']][i]==content for i in range(num_len)]) == num_len * times
          solver.add(frequency_c)
      
      #define frequency
      if 'freqIf' in col:
        for i in range(int(len(col['freqIf'])/2)):
          content = col['freqIf'][2*i]
          times = col['freqIf'][2*i+1]
          special_value += num_len * times
          freqIf_c = z3.Sum([exec(d[col['name']][i]+content,d[col['name']]) for i in range(num_len)]) == num_len * times
          solver.add(freqIf_c)

      if 'empty' in col:
        times = col['empty']
        special_value += times
        if col['type'] == 'Int':
          empty_c = z3.Sum([d[col['name']][i] == 999999 for i in range(num_len)]) == times
        elif col['type'] == 'Real':
          empty_c = z3.Sum([d[col['name']][i] == 1.12345 for i in range(num_len)]) == times
        elif col['type'] == 'String':
          empty_c = z3.Sum([d[col['name']][i] == '' for i in range(num_len)]) == times

        solver.add(empty_c)

      #define enum
      if 'enum' in col:
        col_enum = col['enum']
        enum_c = [z3.Or([d[col['name']][i] == col_enum[j] for j in range(len(col_enum))])
                for i in range(num_len)]
        solver.add(enum_c)
      
      #define distinct
      if 'distinct' in col:
        col_distinct = col['distinct']
        if col_distinct == 'true':
          distinct_c = z3.Distinct([d[col['name']][i] for i in range(num_len)])
          solver.add(distinct_c)

      #define distribution
      if 'distribution' in col:
        col_distri = col['distribution']
        if col_distri == 'Stable':
          # 方差
          var_c = [z3.And(z3.Sum([(d[col['name']][i]-z3.Sum(d[col['name']])/num_len)**2 for i in range(num_len)])/num_len < 2,
                      z3.Sum([(d[col['name']][i]-z3.Sum(d[col['name']])/num_len)**2 for i in range(num_len)])/num_len > 0)  
                  for i in range(num_len)]
          solver.add(var_c)
        if col_distri == 'BlowUp':
          # 递增
          a = z3.Real('a')
          asc_c = [z3.And(d[col['name']][i]<d[col['name']][i+1], a > 1, a < 1.01)  for i in range(num_len-1)]
          # asc_c = [d[col['name']][i]<d[col['name']][i+1] for i in range(num_len-1)]
          solver.add(asc_c)
        if col_distri == 'period':
          fre = 3
          fre_len = num_len//fre
          #分布
          distri_c = [d[col['name']][i]<d[col['name']][i+1] if i< fre_len//2 else d[col['name']][i]>d[col['name']][i+1] for i in range(fre_len)]
          # 周期
          period_c = [z3.And(d[col['name']][fre_len*j+i]<=d[col['name']][i+1],d[col['name']][fre_len*j+i]>=d[col['name']][i]) if i< fre_len//2 
                      else z3.And(d[col['name']][fre_len*j+i]>=d[col['name']][i+1],d[col['name']][fre_len*j+i]<=d[col['name']][i])
                      for i in range(fre_len) for j in range(1,fre)]
          solver.add(distri_c+period_c)

      # 随机数
      if 'type' in col and (col['type']=='Int' or col['type']=='Real' ) and not 'distribution' in col:
        # print(random_num,random_list)
        random_num = num_len - special_value
        random_c = z3.Sum([d[col['name']][i]==random_list[i] for i in range(num_len)]) == random_num
        solver.add(random_c)

          
    # print(d)
    output = []
    if solver.check()==z3.sat:
      m = solver.model()
      for i in range(num_len):
        data = {}
        
        for col in columns:
          if 'type' in col:
            if col['type'] == 'Int':
              data[col['name']] = None if m[d[col['name']][i]].as_long() == 999999 else m[d[col['name']][i]].as_long()
            elif col['type'] == 'Real':
              if float(m[d[col['name']][i]].numerator_as_long())/float(m[d[col['name']][i]].denominator_as_long()) == 1.12345:
                data[col['name']] = None
              else:
                data[col['name']] = float(m[d[col['name']][i]].numerator_as_long())/float(m[d[col['name']][i]].denominator_as_long())  
            elif col['type'] == 'String':
              data[col['name']] = None if m[d[col['name']][i]]=='' else eval(str(m[d[col['name']][i]]))
            elif col['type'] == 'Date':
              if i < len(others[col['name']]):
                data[col['name']] = others[col['name']][i]
              else:
                data[col['name']] = ''
            elif col['type'] == 'Faker':
              data[col['name']] = others[col['name']][i]
          else:
            data[col['name']] = round(np.random.uniform(0,10000),2)
        output.append(data)
      # print(output)
      parse2csv(output,str(index))
    else:
      print('无解')
    res.extend(output)
  AllRes.append(res)

AllRes
# Out:
# soving table……
# [{'$Length(20)$And$BlowUpDistribution(index)$And$ColNum(10)': {'index': '$Int$And$Range(10,50)', 'col1': '$Int$And$Repeat(2,2)$And$Empty(1)', 'col2': '$String$And$Empty(5)', 'col3': '$Int$And$Frequency(6,0.4,5,0.3)$And$Empty(2)', 'col4': '$Real$And$FreqIf(>6,0.4)', 'col5': '$Faker(name)$And$Empty(1)$And$Repeat(3)', 'col6': '$Faker(phone_number)'}}]
# [4]
# [{'index': 0, 'col1': 5, 'col2': None, 'col3': 6, 'col4': 87.56, 'col5': '王龙', 'col6': '13631409570'}, {'index': 1, 'col1': 10, 'col2': 'C', 'col3': 5, 'col4': 86.21, 'col5': '陈桂香', 'col6': '13337557783'}, {'index': 2, 'col1': 5, 'col2': None, 'col3': 5, 'col4': 27.77, 'col5': '陈桂香', 'col6': '13330587722'}, {'index': 3, 'col1': 5, 'col2': 'D', 'col3': 89, 'col4': 55.09, 'col5': '游洋', 'col6': '18906867408'}, {'index': 4, 'col1': 14, 'col2': 'E', 'col3': 6, 'col4': 76.72, 'col5': None, 'col6': '13235163089'}, {'index': 5, 'col1': None, 'col2': None, 'col3': None, 'col4': 98.46, 'col5': '李亮', 'col6': '18994065444'}, {'index': 6, 'col1': 9, 'col2': 'A', 'col3': 5, 'col4': 2.0, 'col5': '武辉', 'col6': '15785542625'}, {'index': 7, 'col1': 5, 'col2': 'B', 'col3': None, 'col4': 24.23, 'col5': '陈桂香', 'col6': '14554249492'}, {'index': 8, 'col1': 5, 'col2': None, 'col3': 6, 'col4': 35.68, 'col5': '张亮', 'col6': '13517701677'}, {'index': 9, 'col1': 21, 'col2': None, 'col3': 6, 'col4': 53.23, 'col5': '杨超', 'col6': '13832941862'}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}], 'length': 10, 'colNum': 6}]
# [4]
# [{'index': 0, 'col1': 26, 'col2': None, 'col3': 5, 'col4': 99.96, 'col5': '杨洋', 'col6': '13238436988', 'col8': 225.44, 'col9': 9423.46, 'col10': 6976.2}, {'index': 1, 'col1': 5, 'col2': None, 'col3': 33, 'col4': 43.81, 'col5': '席鑫', 'col6': '13937090499', 'col8': 5865.61, 'col9': 51.48, 'col10': 1547.63}, {'index': 2, 'col1': 5, 'col2': None, 'col3': None, 'col4': 43.21, 'col5': '丁桂荣', 'col6': '15665759007', 'col8': 4665.74, 'col9': 1797.0, 'col10': 3216.0}, {'index': 3, 'col1': 0, 'col2': None, 'col3': 6, 'col4': 34.05, 'col5': '王浩', 'col6': '18692887205', 'col8': 4346.22, 'col9': 6897.4, 'col10': 3909.55}, {'index': 4, 'col1': None, 'col2': None, 'col3': 5, 'col4': 57.49, 'col5': None, 'col6': '14584038822', 'col8': 3142.46, 'col9': 6781.95, 'col10': 2590.48}, {'index': 5, 'col1': 91, 'col2': None, 'col3': 6, 'col4': 19.98, 'col5': '康淑华', 'col6': '15827175118', 'col8': 6352.44, 'col9': 6146.67, 'col10': 906.77}, {'index': 6, 'col1': 91, 'col2': 'a', 'col3': 6, 'col4': 55.06, 'col5': '邓佳', 'col6': '18102620704', 'col8': 6730.29, 'col9': 7743.64, 'col10': 8425.51}, {'index': 7, 'col1': 5, 'col2': None, 'col3': None, 'col4': 38.63, 'col5': '席鑫', 'col6': '15664416031', 'col8': 8339.86, 'col9': 7107.04, 'col10': 6940.33}, {'index': 8, 'col1': 5, 'col2': 'a', 'col3': 6, 'col4': 5.67, 'col5': '席鑫', 'col6': '15087823604', 'col8': 4064.63, 'col9': 2623.16, 'col10': 8162.35}, {'index': 9, 'col1': 5, 'col2': None, 'col3': 5, 'col4': 44.95, 'col5': '王杨', 'col6': '15508435643', 'col8': 6149.82, 'col9': 2840.67, 'col10': 7402.04}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1}, {'name': 'col2', 'type': 'String', 'repeat': ['a', 2]}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 
': 838.63}, {'index': 15, 'col1': 47, 'col2': 'G', 'col3': 81, 'col4': 89.73, 'col5': '王志强', 'col6': '13964252686', 'col8': 2960.92, 'col9': 5070.6, 'col10': 4846.25}, {'index': 16, 'col1': 94, 'col2': 'E', 'col3': 24, 'col4': 55.21, 'col5': '王志强', 'col6': '18803123174', 'col8': 6453.06, 'col9': 3923.46, 'col10': 2744.32}, {'index': 17, 'col1': 34, 'col2': 'I', 'col3': None, 'col4': 97.76, 'col5': '欧阳晨', 'col6': '18014325382', 'col8': 9061.81, 'col9': 8036.3, 'col10': 1542.5}, {'index': 18, 'col1': 83, 'col2': 'B', 'col3': 6, 'col4': 10.73, 'col5': '巩林', 'col6': '18184511625', 'col8': 1099.13, 'col9': 5057.34, 'col10': 766.04}, {'index': 19, 'col1': 45, 'col2': 'M', 'col3': 6, 'col4': 47.69, 'col5': '李岩', 'col6': '15946702961', 'col8': 6635.5, 'col9': 2095.1, 'col10': 7599.88}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}, {'name': 'col8'}, {'name': 'col9'}, {'name': 'col10'}], 'length': 20, 'colNum': 10}]
# [3]
# [{'index': 0, 'col1': 62, 'col2': None, 'col3': 99, 'col4': 66.91, 'col5': '曹柳', 'col6': '15735908069'}, {'index': 1, 'col1': 2, 'col2': None, 'col3': 6, 'col4': 5.56, 'col5': '寇春梅', 'col6': '15229899828'}, {'index': 2, 'col1': 45, 'col2': 'D', 'col3': 5, 'col4': 60.97, 'col5': '李慧', 'col6': '15986542920'}, {'index': 3, 'col1': None, 'col2': 'A', 'col3': 5, 'col4': 30.72, 'col5': None, 'col6': '13831393680'}, {'index': 4, 'col1': 21, 'col2': 'C', 'col3': 6, 'col4': 91.64, 'col5': '崔红梅', 'col6': '14795633065'}, {'index': 5, 'col1': 92, 'col2': None, 'col3': 5, 'col4': 44.68, 'col5': '郭红', 'col6': '14718526915'}, {'index': 6, 'col1': 53, 'col2': 'E', 'col3': 6, 'col4': 77.77, 'col5': '王帅', 'col6': '14562929199'}, {'index': 7, 'col1': 26, 'col2': 'B', 'col3': None, 'col4': 81.43, 'col5': '陈军', 'col6': '15025582689'}, {'index': 8, 'col1': 78, 'col2': None, 'col3': None, 'col4': 26.22, 'col5': '寇春梅', 'col6': '18954216661'}, {'index': 9, 'col1': 2, 'col2': None, 'col3': 6, 'col4': 16.4, 'col5': '寇春梅', 'col6': '13150141509'}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}], 'length': 10, 'colNum': 6}]
# [2]
# [{'index': 0, 'col1': 35, 'col2': None, 'col3': None, 'col4': 85.22, 'col5': '罗宇', 'col6': '14540460135', 'col8': 3615.57, 'col9': 8347.65, 'col10': 6016.74}, {'index': 1, 'col1': 2, 'col2': None, 'col3': 6, 'col4': 63.41, 'col5': '罗宇', 'col6': '15100208854', 'col8': 324.02, 'col9': 2337.45, 'col10': 3705.7}, {'index': 2, 'col1': None, 'col2': 'E', 'col3': 6, 'col4': 16.3, 'col5': None, 'col6': '13554978810', 'col8': 7784.41, 'col9': 9591.29, 'col10': 7631.61}, {'index': 3, 'col1': 33, 'col2': 'C', 'col3': 5, 'col4': 96.27, 'col5': '蓝坤', 'col6': '18021560985', 'col8': 511.1, 'col9': 3412.43, 'col10': 6568.64}, {'index': 4, 'col1': 12, 'col2': None, 'col3': 5, 'col4': 55.27, 'col5': '王玲', 'col6': '15867378705', 'col8': 7655.45, 'col9': 5361.88, 'col10': 4031.18}, {'index': 5, 'col1': 80, 'col2': 'B', 'col3': None, 'col4': 24.26, 'col5': '罗宇', 'col6': '13557844479', 'col8': 5797.21, 'col9': 7649.59, 'col10': 9904.39}, {'index': 6, 'col1': 59, 'col2': 'D', 'col3': 6, 'col4': 76.82, 'col5': '孙兰英', 'col6': '15833793940', 'col8': 4751.22, 'col9': 3975.47, 'col10': 5528.77}, {'index': 7, 'col1': 78, 'col2': None, 'col3': 6, 'col4': 85.02, 'col5': '许佳', 'col6': '18727509239', 'col8': 175.33, 'col9': 2872.16, 'col10': 6474.28}, {'index': 8, 'col1': 2, 'col2': None, 'col3': 98, 'col4': 35.83, 'col5': '杨龙', 'col6': '13391482807', 'col8': 4034.97, 'col9': 544.71, 'col10': 4728.09}, {'index': 9, 'col1': 84, 'col2': 'A', 'col3': 5, 'col4': 3.66, 'col5': '李浩', 'col6': '15868288485', 'col8': 7931.12, 'col9': 221.3, 'col10': 1837.97}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}, {'name': 'col8'}, {'name': 'col9'}, {'name': 'col10'}], 'length': 10, 'colNum': 10}]
# [13]
# [{'index': 0, 'col1': 62, 'col2': 'H', 'col3': 5, 'col4': 81.59, 'col5': '张利', 'col6': '18654197800'}, {'index': 1, 'col1': 2, 'col2': 'N', 'col3': None, 'col4': 79.16, 'col5': '陈梅', 'col6': '18810274490'}, {'index': 2, 'col1': 33, 'col2': 'I', 'col3': 5, 'col4': 39.18, 'col5': '陈想', 'col6': '14726185891'}, {'index': 3, 'col1': 56, '
9, 'col9': 9986.56, 'col10': 6813.97}, {'index': 18, 'col1': 5, 'col2': 'L', 'col3': 35, 'col4': 13.01, 'col5': '王亮', 'col6': '13833026043', 'col8': 9250.5, 'col9': 5192.31, 'col10': 5835.75}, {'index': 19, 'col1': 15, 'col2': 'G', 'col3': 6, 'col4': 10.32, 'col5': '高兵', 'col6': '14768136194', 'col8': 5075.11, 'col9': 5607.69, 'col10': 8908.44}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [0, 20], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}, {'name': 'col8'}, {'name': 'col9'}, {'name': 'col10'}], 'length': 20, 'colNum': 10}]
# [4]
# [{'index': 10, 'col1': 5, 'col2': None, 'col3': 5, 'col4': 12.23, 'col5': '姜秀荣', 'col6': '13307370086'}, {'index': 11, 'col1': 28, 'col2': 'B', 'col3': None, 'col4': 14.12, 'col5': '臧建华', 'col6': '18758989671'}, {'index': 12, 'col1': 5, 'col2': None, 'col3': 6, 'col4': 66.26, 'col5': '臧建华', 'col6': '13334955889'}, {'index': 13, 'col1': 47, 'col2': 'A', 'col3': 6, 'col4': 95.66, 'col5': '陆荣', 'col6': '13901238938'}, {'index': 14, 'col1': 5, 'col2': None, 'col3': None, 'col4': 2.28, 'col5': None, 'col6': '13878078182'}, {'index': 15, 'col1': 23, 'col2': 'E', 'col3': 6, 'col4': 54.49, 'col5': '杨秀荣', 'col6': '13377477927'}, {'index': 16, 'col1': 5, 'col2': 'D', 'col3': 5, 'col4': 67.84, 'col5': '许畅', 'col6': '14798439820'}, {'index': 17, 'col1': 43, 'col2': 'C', 'col3': 5, 'col4': 68.96, 'col5': '臧建华', 'col6': '15019461823'}, {'index': 18, 'col1': None, 'col2': None, 'col3': 14, 'col4': 30.47, 'col5': '李婷婷', 'col6': '13850664325'}, {'index': 19, 'col1': 5, 'col2': None, 'col3': 6, 'col4': 80.39, 'col5': '姚雷', 'col6': '14508429231'}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [10, 50], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [5, 5], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}], 'length': 10, 'colNum': 6}]
# [9]
'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}, {'name': 'col8'}, {'name': 'col9'}, {'name': 'col10'}], 'length': 20, 'colNum': 10}]
# [4]
# [{'index': 10, 'col1': 29, 'col2': None, 'col3': 5, 'col4': 95.48, 'col5': '郑华', 'col6': '18621680781'}, {'index': 11, 'col1': 12, 'col2': 'E', 'col3': 6, 'col4': 19.43, 'col5': '郑华', 'col6': '18226603702'}, {'index': 12, 'col1': 65, 'col2': 'C', 'col3': None, 'col4': 63.17, 'col5': '雷岩', 'col6': '18134777119'}, {'index': 13, 'col1': None, 'col2': None, 'col3': None, 'col4': 69.18, 'col5': '张丽', 'col6': '18578964864'}, {'index': 14, 'col1': 2, 'col2': 'B', 'col3': 5, 'col4': 24.32, 'col5': None, 'col6': '18583863950'}, {'index': 15, 'col1': 1, 'col2': None, 'col3': 5, 'col4': 34.59, 'col5': '曾林', 'col6': '15792488357'}, {'index': 16, 'col1': 2, 'col2': None, 'col3': 6, 'col4': 30.8, 'col5': '郑华', 'col6': '18018348719'}, {'index': 17, 'col1': 51, 'col2': None, 'col3': 6, 'col4': 87.14, 'col5': '黄淑兰', 'col6': '15163758844'}, {'index': 18, 'col1': 62, 'col2': 'A', 'col3': 6, 'col4': 50.99, 'col5': '罗秀梅', 'col6': '15256252842'}, {'index': 19, 'col1': 26, 'col2': 'D', 'col3': 72, 'col4': 27.09, 'col5': '盛璐', 'col6': '13751369798'}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [10, 50], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}], 'length': 10, 'colNum': 6}]
# [1]
# [{'index': 10, 'col1': 2, 'col2': 'D', 'col3': 6, 'col4': 13.08, 'col5': '林丽华', 'col6': '18645634812', 'col8': 6177.43, 'col9': 5001.03, 'col10': 5720.19}, {'index': 11, 'col1': 38, 'col2': 'E', 'col3': None, 'col4': 1.85, 'col5': None, 'col6': '13418233146', 'col8': 7048.03, 'col9': 5882.03, 'col10': 6142.31}, {'index': 12, 'col1': None, 'col2': None, 'col3': 5, 'col4': 5.51, 'col5': '周淑华', 'col6': '15075470902', 'col8': 9456.12, 'col9': 8243.58, 'col10': 5910.65}, {'index': 13, 'col1': 62, 'col2': 'A', 'col3': 6, 'col4': 17.07, 'col5': '林丽华', 'col6': '13861423769', 'col8': 2026.91, 'col9': 3761.49, 'col10': 6659.04}, {'index': 14, 'col1': 48, 'col2': None, 'col3': 6, 'col4': 72.35, 'col5': '普英', 'col6': '15810463226', 'col8': 3874.03, 'col9': 6004.14, 'col10': 2279.58}, {'index': 15, 'col1': 94, 'col2': None, 'col3
 'col3': 5, 'col4': 0.28, 'col5': '姜飞', 'col6': '13766957931'}, {'index': 23, 'col1': 34, 'col2': 'J', 'col3': 6, 'col4': 67.18, 'col5': '谢雪', 'col6': '13147166976'}, {'index': 24, 'col1': 28, 'col2': None, 'col3': 68, 'col4': 55.27, 'col5': '陈丽娟', 'col6': '13454574233'}, {'index': 25, 'col1': 97, 'col2': 'B', 'col3': 5, 'col4': 99.98, 'col5': None, 'col6': '18075993183'}, {'index': 26, 'col1': 57, 'col2': 'L', 'col3': None, 'col4': 45.22, 'col5': '冀荣', 'col6': '13933464207'}, {'index': 27, 'col1': 99, 'col2': 'A', 'col3': 6, 'col4': 40.78, 'col5': '邢建军', 'col6': '13242152739'}, {'index': 28, 'col1': 24, 'col2': 'C', 'col3': 6, 'col4': 6.93, 'col5': '夏淑兰', 'col6': '14557982802'}, {'index': 29, 'col1': 2, 'col2': 'D', 'col3': 6, 'col4': 32.8, 'col5': '黄秀珍', 'col6': '15513265015'}]
# soving table……
# [{'children': [{'name': 'index', 'type': 'Int', 'range': [10, 50], 'distribution': 'BlowUp'}, {'name': 'col1', 'type': 'Int', 'repeat': [2, 2], 'empty': 1}, {'name': 'col2', 'type': 'String', 'empty': 5}, {'name': 'col3', 'type': 'Int', 'frequency': [6, 0.4, 5, 0.3], 'empty': 2}, {'name': 'col4', 'type': 'Real'}, {'name': 'col5', 'type': 'Faker', 'content': 'name', 'empty': 1, 'repeat': [3]}, {'name': 'col6', 'type': 'Faker', 'content': 'phone_number'}], 'length': 20, 'colNum': 6}]
# [6]
# [{'index': 10, 'col1': 66, 'col2': 'E', 'col3': 6, 'col4': 93.95, 'col5': '杜小红', 'col6': '18650188083', 'col8': 7149.65, 'col9': 5945.13, 'col10': 6830.8}, {'index': 11, 'col1': 52, 'col2': 'H', 'col3': None, 'col4': 51.12, 'col5': '冯英', 'col6': '18002067067', 'col8': 2344.93, 'col9': 7809.09, 'col10': 1651.41}, {'index': 12, 'col1': 2, 'col2': 'C', 'col3': 6, 'col4': 7.66, 'col5': '杜小红', 'col6': '15690027452', 'col8': 9151.59, 'col9': 5151.56, 'col10': 6804.09}, {'index': 13, 'col1': 74, 'col2': None, 'col3': 5, 'col4': 37.17, 'col5': '李飞', 'col6': '14576130471', 'col8': 5959.61, 'col9': 2002.92, 'col10': 3048.57}, {'index': 14, 'col1': 81, 'col2': None, 'col3': 6, 'col4': 55.43, 'col5': '刘晨', 'col6': '13462205216', 'col8': 3645.53, 'col9': 4175.14, 'col10': 9351.39}, {'index': 15, 'col1': 31, 'col2': 'K', 'col3': 77, 'col4': 0.5, 'col5': '柴宁', 'col6': '13127799915', 'col8': 787.79, 'col9': 3936.47, 'col10': 7250.54}, {'index': 16, 'col1': 49, 'col2': 'N', 'col3': 5, 'col4': 12.56, 'col5': None, 'col6': '13850872499', 'col8': 5232.54, 'col9': 2794.15, 'col10': 8884.59}, {'index': 17, 'col1': 38, 'col2': 'F', 'col3': 6, 'col4': 52.35, 'col5': '程勇', 'col6': '13892189716', 'col8': 9052.46, 'col9': 1806.86, 'col10': 6221.23}, {'index': 18, 'col1': 90, 'col2': 'D', 'col3': 3, 'col4': 56.12, 'col5': '陈俊', 'col6': '13991327996', 'col8': 3304.36, 'col9': 1020.93, 'col10': 4532.04}, {'index': 19, 'col1': 97, 'col2': None, 'col3': 50, 'col4': 74.58, 'col5': '王瑜', 'col6': '18026231629', 'col8': 7291.13, 'col9': 7739.07, 'col10': 1039.58}, {'index': 20, 'col1': 2, 'col2': 'O', 'col3': 6, 'col4': 37.84, 'col5': '蒋红', 'col6': '18580792530', 'col8': 2490.43, 'col9': 8985.12, 'col10': 580.85}, {'index': 21, 'col1': 68, 'col2': 'J', 'col3': 6, 'col4': 44.33, 'col5': '司玉梅', 'col6': '15322734538', 'col8': 1425.59, 'col9': 735.9, 'col10': 2805.85}, {'index': 22, 'col1': 53, 'col2': 'M', 'col3': 5, 'col4': 31.46, 'col5': '蔡梅', 'col6': '18966055497', 'col8': 6527.58, 'col9': 6514.53, 'col10': 9839.31}, {'index': 23, 'col1': 41, 'col2': 'B', 'col3': 18, 'col4': 42.4, 'col5': '万佳', 'col6': '13467269651', 'col8': 6398.98, 'col9': 9118.46, 'col10': 7922.16}, {'index': 24, 'col1': 42, 'col2': None, 'col3': 6, 'col4': 4.86, 'col5': '关斌', 'col6': '18787395131', 'col8': 578.64, 'col9': 6236.26, 'col10': 7380.89}, {'index': 25, 'col1': 10, 'col2': 'L', 'col3': 5, 'col4': 40.46, 'col5': '杜小红', 'col6': '13425163079', 'col8': 512.67, 'col9': 4271.85, 'col10': 5044.58}, {'index': 26, 'col1': 27, 'col2': 'A', 'col3': None, 'col4': 32.59, 'col5': '唐玉英', 'col6': '18752095310', 'col8': 143.88, 'col9': 9235.34, 'col10': 3590.18}, {'index': 27, 'col1': 13, 'col2': 'G', 'col3': 5, 'col4': 4.53, 'col5': '周岩', 'col6': '13088585830', 'col8': 3240.82, 'col9': 8476.07, 'col10': 5430.18}, {'index': 28, 'col1': 50, 'col2': 'I', 'col3': 5, 'col4': 87.24, 'col5': '刘建平', 'col6': '13305003024', 'col8': 6000.47, 'col9': 4596.14, 'col10': 9182.21}, {'index': 29, 'col1': None, 'col2': None, 'col3': 6, 'col4': 17.87, 'col5': '黄玲', 'col6': '15305139878', 'col8': 9183.37, 'col9': 2183.9, 'col10': 9382.58}]
# [[{'index': 0,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 87.56,
#    'col5': '王龙',
#    'col6': '13631409570'},
#   {'index': 1,
#    'col1': 10,
#    'col2': 'C',
#    'col3': 5,
#    'col4': 86.21,
#    'col5': '陈桂香',
#    'col6': '13337557783'},
#   {'index': 2,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 27.77,
#    'col5': '陈桂香',
#    'col6': '13330587722'},
#   {'index': 3,
#    'col1': 5,
#    'col2': 'D',
#    'col3': 89,
#    'col4': 55.09,
#    'col5': '游洋',
#    'col6': '18906867408'},
#   {'index': 4,
#    'col1': 14,
#    'col2': 'E',
#    'col3': 6,
#    'col4': 76.72,
#    'col5': None,
#    'col6': '13235163089'},
#   {'index': 5,
#    'col1': None,
#    'col2': None,
#    'col3': None,
#    'col4': 98.46,
#    'col5': '李亮',
#    'col6': '18994065444'},
#   {'index': 6,
#    'col1': 9,
#    'col2': 'A',
#    'col3': 5,
#    'col4': 2.0,
#    'col5': '武辉',
#    'col6': '15785542625'},
#   {'index': 7,
#    'col1': 5,
#    'col2': 'B',
#    'col3': None,
#    'col4': 24.23,
#    'col5': '陈桂香',
#    'col6': '14554249492'},
#   {'index': 8,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 35.68,
#    'col5': '张亮',
#    'col6': '13517701677'},
#   {'index': 9,
#    'col1': 21,
#    'col2': None,
#    'col3': 6,
#    'col4': 53.23,
#    'col5': '杨超',
#    'col6': '13832941862'}],
#  [{'index': 0,
#    'col1': 26,
#    'col2': None,
#    'col3': 5,
#    'col4': 99.96,
#    'col5': '杨洋',
#    'col6': '13238436988',
#    'col8': 225.44,
#    'col9': 9423.46,
#    'col10': 6976.2},
#   {'index': 1,
#    'col1': 5,
#    'col2': None,
#    'col3': 33,
#    'col4': 43.81,
#    'col5': '席鑫',
#    'col6': '13937090499',
#    'col8': 5865.61,
#    'col9': 51.48,
#    'col10': 1547.63},
#   {'index': 2,
#    'col1': 5,
#    'col2': None,
#    'col3': None,
#    'col4': 43.21,
#    'col5': '丁桂荣',
#    'col6': '15665759007',
#    'col8': 4665.74,
#    'col9': 1797.0,
#    'col10': 3216.0},
#   {'index': 3,
#    'col1': 0,
#    'col2': None,
#    'col3': 6,
#    'col4': 34.05,
#    'col5': '王浩',
#    'col6': '18692887205',
#    'col8': 4346.22,
#    'col9': 6897.4,
#    'col10': 3909.55},
#   {'index': 4,
#    'col1': None,
#    'col2': None,
#    'col3': 5,
#    'col4': 57.49,
#    'col5': None,
#    'col6': '14584038822',
#    'col8': 3142.46,
#    'col9': 6781.95,
#    'col10': 2590.48},
#   {'index': 5,
#    'col1': 91,
#    'col2': None,
#    'col3': 6,
#    'col4': 19.98,
#    'col5': '康淑华',
#    'col6': '15827175118',
#    'col8': 6352.44,
#    'col9': 6146.67,
#    'col10': 906.77},
#   {'index': 6,
#    'col1': 91,
#    'col2': 'a',
#    'col3': 6,
#    'col4': 55.06,
#    'col5': '邓佳',
#    'col6': '18102620704',
#    'col8': 6730.29,
#    'col9': 7743.64,
#    'col10': 8425.51},
#   {'index': 7,
#    'col1': 5,
#    'col2': None,
#    'col3': None,
#    'col4': 38.63,
#    'col5': '席鑫',
#    'col6': '15664416031',
#    'col8': 8339.86,
#    'col9': 7107.04,
#    'col10': 6940.33},
#   {'index': 8,
#    'col1': 5,
#    'col2': 'a',
#    'col3': 6,
#    'col4': 5.67,
#    'col5': '席鑫',
#    'col6': '15087823604',
#    'col8': 4064.63,
#    'col9': 2623.16,
#    'col10': 8162.35},
#   {'index': 9,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 44.95,
#    'col5': '王杨',
#    'col6': '15508435643',
#    'col8': 6149.82,
#    'col9': 2840.67,
#    'col10': 7402.04}],
#  [{'index': 0,
#    'col1': 93,
#    'col2': None,
#    'col3': 5,
#    'col4': 64.07,
#    'col5': '刘秀珍',
#    'col6': '18151506680'},
#   {'index': 1,
#    'col1': 17,
#    'col2': 'a',
#    'col3': 6,
#    'col4': 63.81,
#    'col5': '赵雷',
#    'col6': '13027936408'},
#   {'index': 2,
#    'col1': 27,
#    'col2': None,
#    'col3': None,
#    'col4': 6.07,
#    'col5': '高楠',
#    'col6': '18222709433'},
#   {'index': 3,
#    'col1': 28,
#    'col2': None,
#    'col3': 10,
#    'col4': 47.04,
#    'col5': '吕淑兰',
#    'col6': '13209660463'},
#   {'index': 4,
#    'col1': 67,
#    'col2': None,
#    'col3': 5,
#    'col4': 95.98,
#    'col5': '薛峰',
#    'col6': '13115891627'},
#   {'index': 5,
#    'col1': 18,
#    'col2': None,
#    'col3': 5,
#    'col4': 32.61,
#    'col5': '王超',
#    'col6': '15827746140'},
#   {'index': 6,
#    'col1': 16,
#    'col2': None,
#    'col3': None,
#    'col4': 66.3,
#    'col5': '尚莹',
#    'col6': '18110190743'},
#   {'index': 7,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 66.26,
#    'col5': '丁杰',
#    'col6': '13588800810'},
#   {'index': 8,
#    'col1': 79,
#    'col2': None,
#    'col3': 5,
#    'col4': 72.89,
#    'col5': '潘宇',
#    'col6': '18952551871'},
#   {'index': 9,
#    'col1': 55,
#    'col2': None,
#    'col3': 8,
#    'col4': 35.7,
#    'col5': '李华',
#    'col6': '13033003506'},
#   {'index': 10,
#    'col1': 76,
#    'col2': None,
#    'col3': 6,
#    'col4': 41.86,
#    'col5': '周斌',
#    'col6': '13270519533'},
#   {'index': 11,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 58.55,
#    'col5': '王健',
#    'col6': '13788726324'},
#   {'index': 12,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 92.02,
#    'col5': '廖凯',
#    'col6': '18074151208'},
#   {'index': 13,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 61.74,
#    'col5': '叶龙',
#    'col6': '13155085938'},
#   {'index': 14,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 85.65,
#    'col5': None,
#    'col6': '15246865293'},
#   {'index': 15,
#    'col1': 42,
#    'col2': None,
#    'col3': 6,
#    'col4': 96.33,
#    'col5': '尚莹',
#    'col6': '13188326868'},
#   {'index': 16,
#    'col1': 5,
#    'col2': None,
#    'col3': 8,
#    'col4': 70.36,
#    'col5': '王婷婷',
#    'col6': '18540595671'},
#   {'index': 17,
#    'col1': 62,
#    'col2': 'a',
#    'col3': 6,
#    'col4': 7.02,
#    'col5': '尚莹',
#    'col6': '18528529928'},
#   {'index': 18,
#    'col1': 11,
#    'col2': None,
#    'col3': 6,
#    'col4': 62.24,
#    'col5': '韦璐',
#    'col6': '18140986253'},
#   {'index': 19,
#    'col1': 9,
#    'col2': None,
#    'col3': 60,
#    'col4': 87.8,
#    'col5': '王桂香',
#    'col6': '15606797821'}],
#  [{'index': 0,
#    'col1': 5,
#    'col2': 'D',
#    'col3': 6,
#    'col4': 21.19,
#    'col5': '张峰',
#    'col6': '15238094209',
#    'col8': 8176.08,
#    'col9': 2989.55,
#    'col10': 693.04},
#   {'index': 1,
#    'col1': 65,
#    'col2': 'N',
#    'col3': 12,
#    'col4': 79.33,
#    'col5': '王志强',
#    'col6': '14791814488',
#    'col8': 5720.68,
#    'col9': 6441.25,
#    'col10': 6081.6},
#   {'index': 2,
#    'col1': 78,
#    'col2': None,
#    'col3': 47,
#    'col4': 18.2,
#    'col5': '李梅',
#    'col6': '18520533669',
#    'col8': 4521.87,
#    'col9': 6037.29,
#    'col10': 3590.93},
#   {'index': 3,
#    'col1': 74,
#    'col2': 'L',
#    'col3': 5,
#    'col4': 23.34,
#    'col5': '李璐',
#    'col6': '13180745556',
#    'col8': 187.51,
#    'col9': 9036.71,
#    'col10': 5008.9},
#   {'index': 4,
#    'col1': 5,
#    'col2': 'A',
#    'col3': 5,
#    'col4': 66.47,
#    'col5': '潘敏',
#    'col6': '15308526808',
#    'col8': 7595.19,
#    'col9': 6796.68,
#    'col10': 4819.15},
#   {'index': 5,
#    'col1': 47,
#    'col2': 'K',
#    'col3': 6,
#    'col4': 95.65,
#    'col5': '陈欢',
#    'col6': '13190739827',
#    'col8': 2462.52,
#    'col9': 8479.86,
#    'col10': 3085.7},
#   {'index': 6,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 96.72,
#    'col5': '李璐',
#    'col6': '14722564026',
#    'col8': 3336.6,
#    'col9': 392.33,
#    'col10': 4796.77},
#   {'index': 7,
#    'col1': 97,
#    'col2': 'F',
#    'col3': 5,
#    'col4': 92.79,
#    'col5': '王文',
#    'col6': '13921918204',
#    'col8': 2183.05,
#    'col9': 2486.68,
#    'col10': 1257.0},
#   {'index': 8,
#    'col1': 5,
#    'col2': None,
#    'col3': None,
#    'col4': 60.87,
#    'col5': None,
#    'col6': '18267774398',
#    'col8': 5428.13,
#    'col9': 535.66,
#    'col10': 970.12},
#   {'index': 9,
#    'col1': 5,
#    'col2': 'O',
#    'col3': 5,
#    'col4': 25.43,
#    'col5': '鞠斌',
#    'col6': '14555410679',
#    'col8': 9765.07,
#    'col9': 7101.71,
#    'col10': 326.09},
#   {'index': 10,
#    'col1': 42,
#    'col2': 'C',
#    'col3': 6,
#    'col4': 50.52,
#    'col5': '张桂芝',
#    'col6': '13060557683',
#    'col8': 912.6,
#    'col9': 573.22,
#    'col10': 149.01},
#   {'index': 11,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 9.31,
#    'col5': '马玲',
#    'col6': '13350157053',
#    'col8': 8028.21,
#    'col9': 4464.31,
#    'col10': 329.05},
#   {'index': 12,
#    'col1': 30,
#    'col2': 'H',
#    'col3': 6,
#    'col4': 59.09,
#    'col5': '方俊',
#    'col6': '13915574894',
#    'col8': 396.46,
#    'col9': 9595.5,
#    'col10': 1418.79},
#   {'index': 13,
#    'col1': 86,
#    'col2': 'J',
#    'col3': 5,
#    'col4': 53.89,
#    'col5': '张佳',
#    'col6': '13896919969',
#    'col8': 8189.83,
#    'col9': 5026.11,
#    'col10': 4530.26},
#   {'index': 14,
#    'col1': 67,
#    'col2': None,
#    'col3': 5,
#    'col4': 55.26,
#    'col5': '李丽',
#    'col6': '15785563134',
#    'col8': 9376.52,
#    'col9': 37.32,
#    'col10': 838.63},
#   {'index': 15,
#    'col1': 47,
#    'col2': 'G',
#    'col3': 81,
#    'col4': 89.73,
#    'col5': '王志强',
#    'col6': '13964252686',
#    'col8': 2960.92,
#    'col9': 5070.6,
#    'col10': 4846.25},
#   {'index': 16,
#    'col1': 94,
#    'col2': 'E',
#    'col3': 24,
#    'col4': 55.21,
# ...
#   {'index': 17,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 95.45,
#    'col5': '赵博',
#    'col6': '18027279231',
#    'col8': 7569.06,
#    'col9': 3051.25,
#    'col10': 6261.83},
#   {'index': 18,
#    'col1': 5,
#    'col2': 'a',
#    'col3': 6,
#    'col4': 78.09,
#    'col5': '王飞',
#    'col6': '13361356240',
#    'col8': 7481.65,
#    'col9': 8774.02,
#    'col10': 9427.01},
#   {'index': 19,
#    'col1': 5,
#    'col2': None,
#    'col3': None,
#    'col4': 26.78,
#    'col5': None,
#    'col6': '14575248465',
#    'col8': 4657.29,
#    'col9': 4756.13,
#    'col10': 3264.66}],
#  [{'index': 10,
#    'col1': 52,
#    'col2': None,
#    'col3': None,
#    'col4': 55.28,
#    'col5': '郭玉华',
#    'col6': '13488674334'},
#   {'index': 11,
#    'col1': 81,
#    'col2': None,
#    'col3': 6,
#    'col4': 72.74,
#    'col5': None,
#    'col6': '18036534893'},
#   {'index': 12,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 34.1,
#    'col5': '杨华',
#    'col6': '13973100691'},
#   {'index': 13,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 41.57,
#    'col5': '刘楠',
#    'col6': '13114531434'},
#   {'index': 14,
#    'col1': 51,
#    'col2': None,
#    'col3': 68,
#    'col4': 77.78,
#    'col5': '高秀梅',
#    'col6': '15035196980'},
#   {'index': 15,
#    'col1': 68,
#    'col2': None,
#    'col3': 40,
#    'col4': 94.9,
#    'col5': '高秀梅',
#    'col6': '14525653798'},
#   {'index': 16,
#    'col1': 84,
#    'col2': None,
#    'col3': 69,
#    'col4': 38.4,
#    'col5': '田成',
#    'col6': '15378777005'},
#   {'index': 17,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 40.26,
#    'col5': '田小红',
#    'col6': '13043535348'},
#   {'index': 18,
#    'col1': 57,
#    'col2': None,
#    'col3': 5,
#    'col4': 99.0,
#    'col5': '李洁',
#    'col6': '15238291839'},
#   {'index': 19,
#    'col1': 72,
#    'col2': None,
#    'col3': None,
#    'col4': 46.35,
#    'col5': '王强',
#    'col6': '18250073461'},
#   {'index': 20,
#    'col1': 42,
#    'col2': None,
#    'col3': 6,
#    'col4': 3.55,
#    'col5': '高秀梅',
#    'col6': '15572893350'},
#   {'index': 21,
#    'col1': 1,
#    'col2': 'a',
#    'col3': 5,
#    'col4': 96.06,
#    'col5': '姜秀珍',
#    'col6': '18793525524'},
#   {'index': 22,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 9.04,
#    'col5': '喻鑫',
#    'col6': '13466418116'},
#   {'index': 23,
#    'col1': 67,
#    'col2': None,
#    'col3': 6,
#    'col4': 94.9,
#    'col5': '詹东',
#    'col6': '13286249135'},
#   {'index': 24,
#    'col1': 5,
#    'col2': 'a',
#    'col3': 9,
#    'col4': 24.18,
#    'col5': '刘佳',
#    'col6': '18623185114'},
#   {'index': 25,
#    'col1': 88,
#    'col2': None,
#    'col3': 5,
#    'col4': 50.51,
#    'col5': '许雪',
#    'col6': '15804737707'},
#   {'index': 26,
#    'col1': 31,
#    'col2': None,
#    'col3': 6,
#    'col4': 23.07,
#    'col5': '高想',
#    'col6': '18986485202'},
#   {'index': 27,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 54.62,
#    'col5': '马红霞',
#    'col6': '18780482880'},
#   {'index': 28,
#    'col1': 88,
#    'col2': None,
#    'col3': 5,
#    'col4': 85.72,
#    'col5': '徐红',
#    'col6': '13314001141'},
#   {'index': 29,
#    'col1': 81,
#    'col2': None,
#    'col3': 5,
#    'col4': 77.16,
#    'col5': '罗超',
#    'col6': '13690945795'}],
#  [{'index': 10,
#    'col1': 15,
#    'col2': None,
#    'col3': 5,
#    'col4': 91.64,
#    'col5': '高鑫',
#    'col6': '13369470497',
#    'col8': 4749.85,
#    'col9': 8308.63,
#    'col10': 6832.12},
#   {'index': 11,
#    'col1': 81,
#    'col2': None,
#    'col3': 67,
#    'col4': 67.72,
#    'col5': '宋兵',
#    'col6': '14753594481',
#    'col8': 8040.27,
#    'col9': 1386.3,
#    'col10': 5937.55},
#   {'index': 12,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 2.71,
#    'col5': '李利',
#    'col6': '18517497676',
#    'col8': 1408.35,
#    'col9': 369.03,
#    'col10': 1539.38},
#   {'index': 13,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 51.41,
#    'col5': '翁文',
#    'col6': '18612654187',
#    'col8': 9786.01,
#    'col9': 8310.84,
#    'col10': 6621.4},
#   {'index': 14,
#    'col1': 13,
#    'col2': None,
#    'col3': 86,
#    'col4': 33.7,
#    'col5': '严建国',
#    'col6': '15021073699',
#    'col8': 58.22,
#    'col9': 7391.45,
#    'col10': 8387.9},
#   {'index': 15,
#    'col1': 58,
#    'col2': None,
#    'col3': 6,
#    'col4': 54.41,
#    'col5': '盛建平',
#    'col6': '14734364424',
#    'col8': 6583.46,
#    'col9': 4126.22,
#    'col10': 6310.89},
#   {'index': 16,
#    'col1': 5,
#    'col2': 'a',
#    'col3': None,
#    'col4': 39.62,
#    'col5': '杨帆',
#    'col6': '15924270016',
#    'col8': 9516.95,
#    'col9': 4834.72,
#    'col10': 3544.03},
#   {'index': 17,
#    'col1': 42,
#    'col2': None,
#    'col3': 5,
#    'col4': 12.63,
#    'col5': '庞慧',
#    'col6': '18942697510',
#    'col8': 9120.13,
#    'col9': 4694.21,
#    'col10': 3699.44},
#   {'index': 18,
#    'col1': 5,
#    'col2': None,
#    'col3': 6,
#    'col4': 58.57,
#    'col5': '刘旭',
#    'col6': '13110274264',
#    'col8': 8741.16,
#    'col9': 8122.32,
#    'col10': 1413.03},
#   {'index': 19,
#    'col1': 98,
#    'col2': None,
#    'col3': 6,
#    'col4': 79.54,
#    'col5': '刘超',
#    'col6': '15994104919',
#    'col8': 6575.02,
#    'col9': 5827.69,
#    'col10': 9243.22},
#   {'index': 20,
#    'col1': 5,
#    'col2': None,
#    'col3': 58,
#    'col4': 42.75,
#    'col5': '黄雷',
#    'col6': '14798439283',
#    'col8': 2260.85,
#    'col9': 2813.62,
#    'col10': 104.48},
#   {'index': 21,
#    'col1': 63,
#    'col2': None,
#    'col3': 6,
#    'col4': 71.66,
#    'col5': '任淑珍',
#    'col6': '18607595305',
#    'col8': 3953.81,
#    'col9': 6961.68,
#    'col10': 8914.99},
#   {'index': 22,
#    'col1': 37,
#    'col2': None,
#    'col3': 68,
#    'col4': 19.85,
#    'col5': '刘婷',
#    'col6': '15788658231',
#    'col8': 3033.09,
#    'col9': 5757.87,
#    'col10': 4757.31},
#   {'index': 23,
#    'col1': 30,
#    'col2': None,
#    'col3': 5,
#    'col4': 3.74,
#    'col5': '刘超',
#    'col6': '13801008089',
#    'col8': 3960.66,
#    'col9': 8612.03,
#    'col10': 2439.83},
#   {'index': 24,
#    'col1': 61,
#    'col2': None,
#    'col3': 6,
#    'col4': 39.24,
#    'col5': None,
#    'col6': '18153104980',
#    'col8': 7050.69,
#    'col9': 4569.71,
#    'col10': 6872.19},
#   {'index': 25,
#    'col1': 62,
#    'col2': None,
#    'col3': 6,
#    'col4': 88.94,
#    'col5': '俞斌',
#    'col6': '13233878104',
#    'col8': 9201.84,
#    'col9': 3866.17,
#    'col10': 8645.82},
#   {'index': 26,
#    'col1': 5,
#    'col2': None,
#    'col3': 5,
#    'col4': 46.27,
#    'col5': '杨军',
#    'col6': '18723872670',
#    'col8': 9893.33,
#    'col9': 2251.96,
#    'col10': 279.27},
#   {'index': 27,
#    'col1': 16,
#    'col2': None,
#    'col3': 5,
#    'col4': 88.07,
#    'col5': '郑洋',
#    'col6': '18175733983',
#    'col8': 7169.01,
#    'col9': 2444.81,
#    'col10': 3768.01},
#   {'index': 28,
#    'col1': 97,
#    'col2': None,
#    'col3': None,
#    'col4': 75.81,
#    'col5': '魏瑞',
#    'col6': '14597576596',
#    'col8': 9689.09,
#    'col9': 9955.63,
#    'col10': 1337.82},
#   {'index': 29,
#    'col1': 51,
#    'col2': 'a',
#    'col3': 5,
#    'col4': 44.02,
#    'col5': '刘超',
#    'col6': '13364510655',
#    'col8': 4916.01,
#    'col9': 1791.95,
#    'col10': 4413.35}],
#  [{'index': 10,
#    'col1': 29,
#    'col2': None,
#    'col3': 5,
#    'col4': 95.48,
#    'col5': '郑华',
#    'col6': '18621680781'},
#   {'index': 11,
#    'col1': 12,
#    'col2': 'E',
#    'col3': 6,
#    'col4': 19.43,
#    'col5': '郑华',
#    'col6': '18226603702'},
#   {'index': 12,
#    'col1': 65,
#    'col2': 'C',
#    'col3': None,
#    'col4': 63.17,
#    'col5': '雷岩',
#    'col6': '18134777119'},
#   {'index': 13,
#    'col1': None,
#    'col2': None,
#    'col3': None,
#    'col4': 69.18,
#    'col5': '张丽',
#    'col6': '18578964864'},
#   {'index': 14,
#    'col1': 2,
#    'col2': 'B',
#    'col3': 5,
#    'col4': 24.32,
#    'col5': None,
#    'col6': '18583863950'},
#   {'index': 15,
#    'col1': 1,
#    'col2': None,
#    'col3': 5,
#    'col4': 34.59,
#    'col5': '曾林',
#    'col6': '15792488357'},
#   {'index': 16,
#    'col1': 2,
#    'col2': None,
#    'col3': 6,
#    'col4': 30.8,
#    'col5': '郑华',
#    'col6': '18018348719'},
#   {'index': 17,
#    'col1': 51,
#    'col2': None,
#    'col3': 6,
#    'col4': 87.14,
#    'col5': '黄淑兰',
#    'col6': '15163758844'},
#   {'index': 18,
#    'col1': 62,
#    'col2': 'A',
#    'col3': 6,
#    'col4': 50.99,
#    'col5': '罗秀梅',
#    'col6': '15256252842'},
#   {'index': 19,
#    'col1': 26,
#    'col2': 'D',
#    'col3': 72,
#    'col4': 27.09,
#    'col5': '盛璐',
#    'col6': '13751369798'}],
#  [{'index': 10,
#    'col1': 2,
#    'col2': 'D',
#    'col3': 6,
#    'col4': 13.08,
#    'col5': '林丽华',
#    'col6': '18645634812',
#    'col8': 6177.43,
#    'col9': 5001.03,
#    'col10': 5720.19},
#   {'index': 11,
#    'col1': 38,
#    'col2': 'E',
#    'col3': None,
#    'col4': 1.85,
#    'col5': None,
#    'col6': '13418233146',
#    'col8': 7048.03,
#    'col9': 5882.03,
#    'col10': 6142.31},
#   {'index': 12,
#    'col1': None,
#    'col2': None,
#    'col3': 5,
#    'col4': 5.51,
#    'col5': '周淑华',
#    'col6': '15075470902',
#    'col8': 9456.12,
#    'col9': 8243.58,
#    'col10': 5910.65},
#   {'index': 13,
#    'col1': 62,
#    'col2': 'A',
#    'col3': 6,
#    'col4': 17.07,
#    'col5': '林丽华',
#    'col6': '13861423769',
#    'col8': 2026.91,
#    'col9': 3761.49,
#    'col10': 6659.04},
#   {'index': 14,
#    'col1': 48,
#    'col2': None,
#    'col3': 6,
#    'col4': 72.35,
#    'col5': '普英',
#    'col6': '15810463226',
#    'col8': 3874.03,
#    'col9': 6004.14,
#    'col10': 2279.58},
#   {'index': 15,
#    'col1': 94,
#    'col2': None,
#    'col3': 58,
#    'col4': 64.72,
#    'col5': '谢军',
#    'col6': '15866832766',
#    'col8': 3924.4,
#    'col9': 7627.59,
#    'col10': 5698.63},
#   {'index': 16,
#    'col1': 2,
#    'col2': 'B',
#    'col3': 5,
#    'col4': 22.0,
#    'col5': '张丽',
#    'col6': '13666728431',
#    'col8': 8382.45,
#    'col9': 9291.63,
#    'col10': 1676.54},
#   {'index': 17,
#    'col1': 47,
#    'col2': None,
#    'col3': 5,
#    'col4': 77.57,
#    'col5': '何辉',
#    'col6': '13992200379',
#    'col8': 4655.66,
#    'col9': 3103.9,
#    'col10': 6130.48},
#   {'index': 18,
#    'col1': 9,
#    'col2': 'C',
#    'col3': 6,
#    'col4': 12.51,
#    'col5': '罗海燕',
#    'col6': '13992230556',
#    'col8': 3234.74,
#    'col9': 4938.25,
#    'col10': 4425.9},
#   {'index': 19,
#    'col1': 61,
#    'col2': None,
#    'col3': None,
#    'col4': 31.27,
#    'col5': '林丽华',
#    'col6': '15239978246',
#    'col8': 4030.03,
#    'col9': 365.69,
#    'col10': 8460.93}],
#  [{'index': 10,
#    'col1': 81,
#    'col2': 'F',
#    'col3': 5,
#    'col4': 80.63,
#    'col5': '秦玉兰',
#    'col6': '15325412979'},
#   {'index': 11,
#    'col1': 79,
#    'col2': 'M',
#    'col3': 6,
#    'col4': 14.36,
#    'col5': '王坤',
#    'col6': '15887465291'},
#   {'index': 12,
#    'col1': 25,
#    'col2': 'O',
#    'col3': 87,
#    'col4': 52.21,
#    'col5': '陈梅',
#    'col6': '14705570518'},
#   {'index': 13,
#    'col1': 17,
#    'col2': 'E',
#    'col3': 6,
#    'col4': 79.54,
#    'col5': '林博',
#    'col6': '18164419668'},
#   {'index': 14,
#    'col1': 77,
#    'col2': None,
#    'col3': None,
#    'col4': 14.87,
#    'col5': '陈海燕',
#    'col6': '13274733937'},
#   {'index': 15,
#    'col1': 61,
#    'col2': 'N',
#    'col3': 5,
#    'col4': 0.11,
#    'col5': '王桂芳',
#    'col6': '15535530304'},
#   {'index': 16,
#    'col1': 2,
#    'col2': 'G',
#    'col3': 5,
#    'col4': 29.57,
#    'col5': '刘燕',
#    'col6': '13162081700'},
#   {'index': 17,
#    'col1': 87,
#    'col2': None,
#    'col3': 5,
#    'col4': 57.5,
#    'col5': '陈海燕',
#    'col6': '18569707577'},
#   {'index': 18,
#    'col1': 28,
#    'col2': 'I',
#    'col3': 6,
#    'col4': 59.03,
#    'col5': '刘超',
#    'col6': '15754506357'},
#   {'index': 19,
#    'col1': 55,
#    'col2': None,
#    'col3': 6,
#    'col4': 82.25,
#    'col5': '傅阳',
#    'col6': '15825815517'},
#   {'index': 20,
#    'col1': None,
#    'col2': None,
#    'col3': 27,
#    'col4': 10.96,
#    'col5': '王玉兰',
#    'col6': '18152225312'},
#   {'index': 21,
#    'col1': 97,
#    'col2': 'K',
#    'col3': 10,
#    'col4': 3.39,
#    'col5': '陈海燕',
#    'col6': '18763023920'},
#   {'index': 22,
#    'col1': 49,
#    'col2': 'H',
#    'col3': 5,
#    'col4': 0.28,
#    'col5': '姜飞',
#    'col6': '13766957931'},
#   {'index': 23,
#    'col1': 34,
#    'col2': 'J',
#    'col3': 6,
#    'col4': 67.18,
#    'col5': '谢雪',
#    'col6': '13147166976'},
#   {'index': 24,
#    'col1': 28,
#    'col2': None,
#    'col3': 68,
#    'col4': 55.27,
#    'col5': '陈丽娟',
#    'col6': '13454574233'},
#   {'index': 25,
#    'col1': 97,
#    'col2': 'B',
#    'col3': 5,
#    'col4': 99.98,
#    'col5': None,
#    'col6': '18075993183'},
#   {'index': 26,
#    'col1': 57,
#    'col2': 'L',
#    'col3': None,
#    'col4': 45.22,
#    'col5': '冀荣',
#    'col6': '13933464207'},
#   {'index': 27,
#    'col1': 99,
#    'col2': 'A',
#    'col3': 6,
#    'col4': 40.78,
#    'col5': '邢建军',
#    'col6': '13242152739'},
#   {'index': 28,
#    'col1': 24,
#    'col2': 'C',
#    'col3': 6,
#    'col4': 6.93,
#    'col5': '夏淑兰',
#    'col6': '14557982802'},
#   {'index': 29,
#    'col1': 2,
#    'col2': 'D',
#    'col3': 6,
#    'col4': 32.8,
#    'col5': '黄秀珍',
#    'col6': '15513265015'}],
#  [{'index': 10,
#    'col1': 66,
#    'col2': 'E',
#    'col3': 6,
#    'col4': 93.95,
#    'col5': '杜小红',
#    'col6': '18650188083',
#    'col8': 7149.65,
#    'col9': 5945.13,
#    'col10': 6830.8},
#   {'index': 11,
#    'col1': 52,
#    'col2': 'H',
#    'col3': None,
#    'col4': 51.12,
#    'col5': '冯英',
#    'col6': '18002067067',
#    'col8': 2344.93,
#    'col9': 7809.09,
#    'col10': 1651.41},
#   {'index': 12,
#    'col1': 2,
#    'col2': 'C',
#    'col3': 6,
#    'col4': 7.66,
#    'col5': '杜小红',
#    'col6': '15690027452',
#    'col8': 9151.59,
#    'col9': 5151.56,
#    'col10': 6804.09},
#   {'index': 13,
#    'col1': 74,
#    'col2': None,
#    'col3': 5,
#    'col4': 37.17,
#    'col5': '李飞',
#    'col6': '14576130471',
#    'col8': 5959.61,
#    'col9': 2002.92,
#    'col10': 3048.57},
#   {'index': 14,
#    'col1': 81,
#    'col2': None,
#    'col3': 6,
#    'col4': 55.43,
#    'col5': '刘晨',
#    'col6': '13462205216',
#    'col8': 3645.53,
#    'col9': 4175.14,
#    'col10': 9351.39},
#   {'index': 15,
#    'col1': 31,
#    'col2': 'K',
#    'col3': 77,
#    'col4': 0.5,
#    'col5': '柴宁',
#    'col6': '13127799915',
#    'col8': 787.79,
#    'col9': 3936.47,
#    'col10': 7250.54},
#   {'index': 16,
#    'col1': 49,
#    'col2': 'N',
#    'col3': 5,
#    'col4': 12.56,
#    'col5': None,
#    'col6': '13850872499',
#    'col8': 5232.54,
#    'col9': 2794.15,
#    'col10': 8884.59},
#   {'index': 17,
#    'col1': 38,
#    'col2': 'F',
#    'col3': 6,
#    'col4': 52.35,
#    'col5': '程勇',
#    'col6': '13892189716',
#    'col8': 9052.46,
#    'col9': 1806.86,
#    'col10': 6221.23},
#   {'index': 18,
#    'col1': 90,
#    'col2': 'D',
#    'col3': 3,
#    'col4': 56.12,
#    'col5': '陈俊',
#    'col6': '13991327996',
#    'col8': 3304.36,
#    'col9': 1020.93,
#    'col10': 4532.04},
#   {'index': 19,
#    'col1': 97,
#    'col2': None,
#    'col3': 50,
#    'col4': 74.58,
#    'col5': '王瑜',
#    'col6': '18026231629',
#    'col8': 7291.13,
#    'col9': 7739.07,
#    'col10': 1039.58},
#   {'index': 20,
#    'col1': 2,
#    'col2': 'O',
#    'col3': 6,
#    'col4': 37.84,
#    'col5': '蒋红',
#    'col6': '18580792530',
#    'col8': 2490.43,
#    'col9': 8985.12,
#    'col10': 580.85},
#   {'index': 21,
#    'col1': 68,
#    'col2': 'J',
#    'col3': 6,
#    'col4': 44.33,
#    'col5': '司玉梅',
#    'col6': '15322734538',
#    'col8': 1425.59,
#    'col9': 735.9,
#    'col10': 2805.85},
#   {'index': 22,
#    'col1': 53,
#    'col2': 'M',
#    'col3': 5,
#    'col4': 31.46,
#    'col5': '蔡梅',
#    'col6': '18966055497',
#    'col8': 6527.58,
#    'col9': 6514.53,
#    'col10': 9839.31},
#   {'index': 23,
#    'col1': 41,
#    'col2': 'B',
#    'col3': 18,
#    'col4': 42.4,
#    'col5': '万佳',
#    'col6': '13467269651',
#    'col8': 6398.98,
#    'col9': 9118.46,
#    'col10': 7922.16},
#   {'index': 24,
#    'col1': 42,
#    'col2': None,
#    'col3': 6,
#    'col4': 4.86,
#    'col5': '关斌',
#    'col6': '18787395131',
#    'col8': 578.64,
#    'col9': 6236.26,
#    'col10': 7380.89},
#   {'index': 25,
#    'col1': 10,
#    'col2': 'L',
#    'col3': 5,
#    'col4': 40.46,
#    'col5': '杜小红',
#    'col6': '13425163079',
#    'col8': 512.67,
#    'col9': 4271.85,
#    'col10': 5044.58},
#   {'index': 26,
#    'col1': 27,
#    'col2': 'A',
#    'col3': None,
#    'col4': 32.59,
#    'col5': '唐玉英',
#    'col6': '18752095310',
#    'col8': 143.88,
#    'col9': 9235.34,
#    'col10': 3590.18},
#   {'index': 27,
#    'col1': 13,
#    'col2': 'G',
#    'col3': 5,
#    'col4': 4.53,
#    'col5': '周岩',
#    'col6': '13088585830',
#    'col8': 3240.82,
#    'col9': 8476.07,
#    'col10': 5430.18},
#   {'index': 28,
#    'col1': 50,
#    'col2': 'I',
#    'col3': 5,
#    'col4': 87.24,
#    'col5': '刘建平',
#    'col6': '13305003024',
#    'col8': 6000.47,
#    'col9': 4596.14,
#    'col10': 9182.21},
#   {'index': 29,
#    'col1': None,
#    'col2': None,
#    'col3': 6,
#    'col4': 17.87,
#    'col5': '黄玲',
#    'col6': '15305139878',
#    'col8': 9183.37,
#    'col9': 2183.9,
#    'col10': 9382.58}]]
